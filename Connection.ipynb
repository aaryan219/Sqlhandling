# %%
# !python -m pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\genesis\appdata\local\programs\python\python38\lib\site-packages (3.5.6)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\genesis\appdata\local\programs\python\python38\lib\site-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").appName("tutorial").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.master("local[*]").appName("tutorial").getOrCreate()
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\site-packages\pyspark\sql\session.py:228, in SparkSession.Builder.getOrCreate(self)
#     226         sparkConf.set(key, value)
#     227     # This SparkContext may be an existing one.
# --> 228     sc = SparkContext.getOrCreate(sparkConf)
#     229 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230 # by all sessions.
#     231 session = SparkSession(sc)
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\site-packages\pyspark\context.py:392, in SparkContext.getOrCreate(cls, conf)
#     390 with SparkContext._lock:
#     391     if SparkContext._active_spark_context is None:
# --> 392         SparkContext(conf=conf or SparkConf())
#     393     return SparkContext._active_spark_context
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\site-packages\pyspark\context.py:144, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     139 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     140     raise ValueError(
#     141         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     142         " is not allowed as it is a security risk.")
# --> 144 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     145 try:
#     146     self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#     147                   conf, jsc, profiler_cls)
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\site-packages\pyspark\context.py:339, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     337 with SparkContext._lock:
#     338     if not SparkContext._gateway:
# --> 339         SparkContext._gateway = gateway or launch_gateway(conf)
#     340         SparkContext._jvm = SparkContext._gateway.jvm
#     342     if instance:
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\site-packages\pyspark\java_gateway.py:101, in launch_gateway(conf, popen_kwargs)
#      98     proc = Popen(command, **popen_kwargs)
#      99 else:
#     100     # preexec_fn not supported on Windows
# --> 101     proc = Popen(command, **popen_kwargs)
#     103 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     104 while not proc.poll() and not os.path.isfile(conn_info_file):
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\subprocess.py:854, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     850         if self.text_mode:
#     851             self.stderr = io.TextIOWrapper(self.stderr,
#     852                     encoding=encoding, errors=errors)
# --> 854     self._execute_child(args, executable, preexec_fn, close_fds,
#     855                         pass_fds, cwd, env,
#     856                         startupinfo, creationflags, shell,
#     857                         p2cread, p2cwrite,
#     858                         c2pread, c2pwrite,
#     859                         errread, errwrite,
#     860                         restore_signals, start_new_session)
#     861 except:
#     862     # Cleanup if the child failed starting.
#     863     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\Genesis\miniconda3\envs\env1\lib\subprocess.py:1307, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1305 # Start the process
#    1306 try:
# -> 1307     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                              # no special security
#    1309                              None, None,
#    1310                              int(not close_fds),
#    1311                              creationflags,
#    1312                              env,
#    1313                              cwd,
#    1314                              startupinfo)
#    1315 finally:
#    1316     # Child is launched. Close the parent's copy of those pipe
#    1317     # handles that only the child should have open.  You need
#    (...)
#    1320     # pipe will not close when the child process exits and the
#    1321     # ReadFile will hang.
#    1322     self._close_pipe_fds(p2cread, p2cwrite,
#    1323                          c2pread, c2pwrite,
#    1324                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Jupyter PySpark") \
    .config("spark.executor.memory", "2g") \
    .config("spark.sql.sources.commitProtocolClass", "org.apache.spark.sql.execution.datasources.SQLHadoopMapReduceCommitProtocol") \
    .config("spark.sql.parquet.output.committer.class", "org.apache.hadoop.mapreduce.lib.output.DirectFileOutputCommitter") \
    .getOrCreate()

# %%
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=localhost;'
    'DATABASE=chinook;'
    'Trusted_Connection=yes;'
)
cursor = conn.cursor()

# %%
df=spark.read.csv("C:\\data_quality\\data\\error_data\\Customer.csv")

# %%
df.show()
# Out:
# +----------+--------------+-------+--------+---------+---------+---------+---------+
# |       _c0|           _c1|    _c2|     _c3|      _c4|      _c5|      _c6|      _c7|
# +----------+--------------+-------+--------+---------+---------+---------+---------+
# |CUSTOMERID|CUSTOMERTYPEID|COUNTRY|LANGUAGE|CREATEDBY|CREATEDAT|CHANGEDBY|CHANGEDAT|
# |         #|             #|      #|       #|       16| 20210603|       16| 20210603|
# |  LACU_S02|            Z1|     US|      EN|       20| 20210603|       20| 20210603|
# |   1000153|            Z3|     CA|      EN|       10| 20210603|       10| 20210603|
# |  LACU_S03|            Z1|     US|      EN|       21| 20210603|       21| 20210603|
# |  LACU_S04|            Z1|     US|      EN|       22| 20210603|       22| 20210603|
# |  LACU_S05|            Z1|     US|      EN|       23| 20210603|       23| 20210603|
# |  CACU_S01|            Z1|     CA|      EN|       11| 20210603|       11| 20210603|
# |  CACU_S02|            Z1|     CA|      EN|       12| 20210603|       12| 20210603|
# |  CACU_S03|            Z1|     CA|      EN|       13| 20210603|       13| 20210603|
# |  USCU_L01|            Z2|     US|      EN|       24| 20210603|       24| 20210603|
# |  USCU_L02|            Z2|     US|      EN|       25| 20210603|       25| 20210603|
# |  USCU_L03|            Z2|     US|      EN|       26| 20210603|       26| 20210603|
# |  USCU_L04|            Z2|     US|      EN|       27| 20210603|       27| 20210603|
# |  USCU_L05|            Z2|     US|      EN|       28| 20210603|       28| 20210603|
# |  CACU_S04|            Z1|     CA|      EN|       14| 20210603|       14| 20210603|
# |  CACU_S05|            Z1|     CA|      EN|       15| 20210603|       15| 20210603|
# |  17100001|            Z3|     CA|      EN|       17| 20210603|       17| 20210603|
# |  17100002|            Z3|     CA|      EN|       18| 20210603|       18| 20210603|
# |  LACU_S01|            Z1|     CA|      EN|       19| 20210603|       19| 20210603|
# +----------+--------------+-------+--------+---------+---------+---------+---------+
# only showing top 20 rows

# %%
cursor.execute("Select * from Invoice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cursor.execute("Select * from Invoice")
#
# NameError: name 'cursor' is not defined

# %%
cursor.fetchall()
# Out:
# [(1, 2, datetime.datetime(2021, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 'UPI'),
#  (2, 4, datetime.datetime(2021, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 'Cash'),
#  (3, 8, datetime.datetime(2021, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 'Credit Card'),
#  (4, 14, datetime.datetime(2021, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 'UPI'),
#  (5, 23, datetime.datetime(2021, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 'Cash'),
#  (6, 37, datetime.datetime(2021, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 'Credit Card'),
#  (7, 38, datetime.datetime(2021, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 'UPI'),
#  (8, 40, datetime.datetime(2021, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 'Cash'),
#  (9, 42, datetime.datetime(2021, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 'Credit Card'),
#  (10, 46, datetime.datetime(2021, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 'UPI'),
#  (11, 52, datetime.datetime(2021, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 'Cash'),
#  (12, 2, datetime.datetime(2021, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 'Credit Card'),
#  (13, 16, datetime.datetime(2021, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 'UPI'),
#  (14, 17, datetime.datetime(2021, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 'Cash'),
#  (15, 19, datetime.datetime(2021, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 'Credit Card'),
#  (16, 21, datetime.datetime(2021, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 'UPI'),
#  (17, 25, datetime.datetime(2021, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 'Cash'),
#  (18, 31, datetime.datetime(2021, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 'Credit Card'),
#  (19, 40, datetime.datetime(2021, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 'UPI'),
#  (20, 54, datetime.datetime(2021, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 'Cash'),
#  (21, 55, datetime.datetime(2021, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 'Credit Card'),
#  (22, 57, datetime.datetime(2021, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 'UPI'),
#  (23, 59, datetime.datetime(2021, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 'Cash'),
#  (24, 4, datetime.datetime(2021, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 'Credit Card'),
#  (25, 10, datetime.datetime(2021, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 'UPI'),
#  (26, 19, datetime.datetime(2021, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 'Cash'),
#  (27, 33, datetime.datetime(2021, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 'Credit Card'),
#  (28, 34, datetime.datetime(2021, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 'UPI'),
#  (29, 36, datetime.datetime(2021, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 'Cash'),
#  (30, 38, datetime.datetime(2021, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 'Credit Card'),
#  (31, 42, datetime.datetime(2021, 5, 7, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('5.94'), 'UPI'),
#  (32, 48, datetime.datetime(2021, 5, 10, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('8.91'), 'Cash'),
#  (33, 57, datetime.datetime(2021, 5, 15, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('13.86'), 'Credit Card'),
#  (34, 12, datetime.datetime(2021, 5, 23, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('0.99'), 'UPI'),
#  (35, 13, datetime.datetime(2021, 6, 5, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('1.98'), 'Cash'),
#  (36, 15, datetime.datetime(2021, 6, 5, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('1.98'), 'Credit Card'),
#  (37, 17, datetime.datetime(2021, 6, 6, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('3.96'), 'UPI'),
#  (38, 21, datetime.datetime(2021, 6, 7, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('5.94'), 'Cash'),
#  (39, 27, datetime.datetime(2021, 6, 10, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('8.91'), 'Credit Card'),
#  (40, 36, datetime.datetime(2021, 6, 15, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('13.86'), 'UPI'),
#  (41, 50, datetime.datetime(2021, 6, 23, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('0.99'), 'Cash'),
#  (42, 51, datetime.datetime(2021, 7, 6, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('1.98'), 'Credit Card'),
#  (43, 53, datetime.datetime(2021, 7, 6, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('1.98'), 'UPI'),
#  (44, 55, datetime.datetime(2021, 7, 7, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('3.96'), 'Cash'),
#  (45, 59, datetime.datetime(2021, 7, 8, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('5.94'), 'Credit Card'),
#  (46, 6, datetime.datetime(2021, 7, 11, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('8.91'), 'UPI'),
#  (47, 15, datetime.datetime(2021, 7, 16, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('13.86'), 'Cash'),
#  (48, 29, datetime.datetime(2021, 7, 24, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('0.99'), 'Credit Card'),
#  (49, 30, datetime.datetime(2021, 8, 6, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('1.98'), 'UPI'),
#  (50, 32, datetime.datetime(2021, 8, 6, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('1.98'), 'Cash'),
#  (51, 34, datetime.datetime(2021, 8, 7, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('3.96'), 'Credit Card'),
#  (52, 38, datetime.datetime(2021, 8, 8, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('5.94'), 'UPI'),
#  (53, 44, datetime.datetime(2021, 8, 11, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('8.91'), 'Cash'),
#  (54, 53, datetime.datetime(2021, 8, 16, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('13.86'), 'Credit Card'),
#  (55, 8, datetime.datetime(2021, 8, 24, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('0.99'), 'UPI'),
#  (56, 9, datetime.datetime(2021, 9, 6, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('1.98'), 'Cash'),
#  (57, 11, datetime.datetime(2021, 9, 6, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('1.98'), 'Credit Card'),
#  (58, 13, datetime.datetime(2021, 9, 7, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('3.96'), 'UPI'),
#  (59, 17, datetime.datetime(2021, 9, 8, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('5.94'), 'Cash'),
#  (60, 23, datetime.datetime(2021, 9, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('8.91'), 'Credit Card'),
#  (61, 32, datetime.datetime(2021, 9, 16, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('13.86'), 'UPI'),
#  (62, 46, datetime.datetime(2021, 9, 24, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('0.99'), 'Cash'),
#  (63, 47, datetime.datetime(2021, 10, 7, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('1.98'), 'Credit Card'),
#  (64, 49, datetime.datetime(2021, 10, 7, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('1.98'), 'UPI'),
#  (65, 51, datetime.datetime(2021, 10, 8, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('3.96'), 'Cash'),
#  (66, 55, datetime.datetime(2021, 10, 9, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('5.94'), 'Credit Card'),
#  (67, 2, datetime.datetime(2021, 10, 12, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('8.91'), 'UPI'),
#  (68, 11, datetime.datetime(2021, 10, 17, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('13.86'), 'Cash'),
#  (69, 25, datetime.datetime(2021, 10, 25, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('0.99'), 'Credit Card'),
#  (70, 26, datetime.datetime(2021, 11, 7, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('1.98'), 'UPI'),
#  (71, 28, datetime.datetime(2021, 11, 7, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('1.98'), 'Cash'),
#  (72, 30, datetime.datetime(2021, 11, 8, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('3.96'), 'Credit Card'),
#  (73, 34, datetime.datetime(2021, 11, 9, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('5.94'), 'UPI'),
#  (74, 40, datetime.datetime(2021, 11, 12, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('8.91'), 'Cash'),
#  (75, 49, datetime.datetime(2021, 11, 17, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('13.86'), 'Credit Card'),
#  (76, 4, datetime.datetime(2021, 11, 25, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('0.99'), 'UPI'),
#  (77, 5, datetime.datetime(2021, 12, 8, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('1.98'), 'Cash'),
#  (78, 7, datetime.datetime(2021, 12, 8, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('1.98'), 'Credit Card'),
#  (79, 9, datetime.datetime(2021, 12, 9, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('3.96'), 'UPI'),
#  (80, 13, datetime.datetime(2021, 12, 10, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('5.94'), 'Cash'),
#  (81, 19, datetime.datetime(2021, 12, 13, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('8.91'), 'Credit Card'),
#  (82, 28, datetime.datetime(2021, 12, 18, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('13.86'), 'UPI'),
#  (83, 42, datetime.datetime(2021, 12, 26, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('0.99'), 'Cash'),
#  (84, 43, datetime.datetime(2022, 1, 8, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('1.98'), 'Credit Card'),
#  (85, 45, datetime.datetime(2022, 1, 8, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('1.98'), 'UPI'),
#  (86, 47, datetime.datetime(2022, 1, 9, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('3.96'), 'Cash'),
#  (87, 51, datetime.datetime(2022, 1, 10, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('6.94'), 'Credit Card'),
#  (88, 57, datetime.datetime(2022, 1, 13, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('17.91'), 'UPI'),
#  (89, 7, datetime.datetime(2022, 1, 18, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('18.86'), 'Cash'),
#  (90, 21, datetime.datetime(2022, 1, 26, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('0.99'), 'Credit Card'),
#  (91, 22, datetime.datetime(2022, 2, 8, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('1.98'), 'UPI'),
#  (92, 24, datetime.datetime(2022, 2, 8, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('1.98'), 'Cash'),
#  (93, 26, datetime.datetime(2022, 2, 9, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('3.96'), 'Credit Card'),
#  (94, 30, datetime.datetime(2022, 2, 10, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('5.94'), 'UPI'),
#  (95, 36, datetime.datetime(2022, 2, 13, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('8.91'), 'Cash'),
#  (96, 45, datetime.datetime(2022, 2, 18, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('21.86'), 'Credit Card'),
#  (97, 59, datetime.datetime(2022, 2, 26, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('1.99'), 'UPI'),
#  (98, 1, datetime.datetime(2022, 3, 11, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('3.98'), 'Cash'),
#  (99, 3, datetime.datetime(2022, 3, 11, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('3.98'), 'Credit Card'),
#  (100, 5, datetime.datetime(2022, 3, 12, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('3.96'), 'UPI'),
#  (101, 9, datetime.datetime(2022, 3, 13, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('5.94'), 'Cash'),
#  (102, 15, datetime.datetime(2022, 3, 16, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('9.91'), 'Credit Card'),
#  (103, 24, datetime.datetime(2022, 3, 21, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('15.86'), 'UPI'),
#  (104, 38, datetime.datetime(2022, 3, 29, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('0.99'), 'Cash'),
#  (105, 39, datetime.datetime(2022, 4, 11, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('1.98'), 'Credit Card'),
#  (106, 41, datetime.datetime(2022, 4, 11, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('1.98'), 'UPI'),
#  (107, 43, datetime.datetime(2022, 4, 12, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('3.96'), 'Cash'),
#  (108, 47, datetime.datetime(2022, 4, 13, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('5.94'), 'Credit Card'),
#  (109, 53, datetime.datetime(2022, 4, 16, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('8.91'), 'UPI'),
#  (110, 3, datetime.datetime(2022, 4, 21, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('13.86'), 'Cash'),
#  (111, 17, datetime.datetime(2022, 4, 29, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('0.99'), 'Credit Card'),
#  (112, 18, datetime.datetime(2022, 5, 12, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('1.98'), 'UPI'),
#  (113, 20, datetime.datetime(2022, 5, 12, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('1.98'), 'Cash'),
#  (114, 22, datetime.datetime(2022, 5, 13, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('3.96'), 'Credit Card'),
#  (115, 26, datetime.datetime(2022, 5, 14, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('5.94'), 'UPI'),
#  (116, 32, datetime.datetime(2022, 5, 17, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('8.91'), 'Cash'),
#  (117, 41, datetime.datetime(2022, 5, 22, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('13.86'), 'Credit Card'),
#  (118, 55, datetime.datetime(2022, 5, 30, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('0.99'), 'UPI'),
#  (119, 56, datetime.datetime(2022, 6, 12, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('1.98'), 'Cash'),
#  (120, 58, datetime.datetime(2022, 6, 12, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('1.98'), 'Credit Card'),
#  (121, 1, datetime.datetime(2022, 6, 13, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('3.96'), 'UPI'),
#  (122, 5, datetime.datetime(2022, 6, 14, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('5.94'), 'Cash'),
#  (123, 11, datetime.datetime(2022, 6, 17, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('8.91'), 'Credit Card'),
#  (124, 20, datetime.datetime(2022, 6, 22, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('13.86'), 'UPI'),
#  (125, 34, datetime.datetime(2022, 6, 30, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('0.99'), 'Cash'),
#  (126, 35, datetime.datetime(2022, 7, 13, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('1.98'), 'Credit Card'),
#  (127, 37, datetime.datetime(2022, 7, 13, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('1.98'), 'UPI'),
#  (128, 39, datetime.datetime(2022, 7, 14, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('3.96'), 'Cash'),
#  (129, 43, datetime.datetime(2022, 7, 15, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('5.94'), 'Credit Card'),
#  (130, 49, datetime.datetime(2022, 7, 18, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('8.91'), 'UPI'),
#  (131, 58, datetime.datetime(2022, 7, 23, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('13.86'), 'Cash'),
#  (132, 13, datetime.datetime(2022, 7, 31, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('0.99'), 'Credit Card'),
#  (133, 14, datetime.datetime(2022, 8, 13, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('1.98'), 'UPI'),
#  (134, 16, datetime.datetime(2022, 8, 13, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('1.98'), 'Cash'),
#  (135, 18, datetime.datetime(2022, 8, 14, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('3.96'), 'Credit Card'),
#  (136, 22, datetime.datetime(2022, 8, 15, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('5.94'), 'UPI'),
#  (137, 28, datetime.datetime(2022, 8, 18, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('8.91'), 'Cash'),
#  (138, 37, datetime.datetime(2022, 8, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('13.86'), 'Credit Card'),
#  (139, 51, datetime.datetime(2022, 8, 31, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('0.99'), 'UPI'),
#  (140, 52, datetime.datetime(2022, 9, 13, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('1.98'), 'Cash'),
#  (141, 54, datetime.datetime(2022, 9, 13, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('1.98'), 'Credit Card'),
#  (142, 56, datetime.datetime(2022, 9, 14, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('3.96'), 'UPI'),
#  (143, 1, datetime.datetime(2022, 9, 15, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('5.94'), 'Cash'),
#  (144, 7, datetime.datetime(2022, 9, 18, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('8.91'), 'Credit Card'),
#  (145, 16, datetime.datetime(2022, 9, 23, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('13.86'), 'UPI'),
#  (146, 30, datetime.datetime(2022, 10, 1, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('0.99'), 'Cash'),
#  (147, 31, datetime.datetime(2022, 10, 14, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('1.98'), 'Credit Card'),
#  (148, 33, datetime.datetime(2022, 10, 14, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('1.98'), 'UPI'),
#  (149, 35, datetime.datetime(2022, 10, 15, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('3.96'), 'Cash'),
#  (150, 39, datetime.datetime(2022, 10, 16, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('5.94'), 'Credit Card'),
#  (151, 45, datetime.datetime(2022, 10, 19, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('8.91'), 'UPI'),
#  (152, 54, datetime.datetime(2022, 10, 24, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('13.86'), 'Cash'),
#  (153, 9, datetime.datetime(2022, 11, 1, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('0.99'), 'Credit Card'),
#  (154, 10, datetime.datetime(2022, 11, 14, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('1.98'), 'UPI'),
#  (155, 12, datetime.datetime(2022, 11, 14, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('1.98'), 'Cash'),
#  (156, 14, datetime.datetime(2022, 11, 15, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('3.96'), 'Credit Card'),
#  (157, 18, datetime.datetime(2022, 11, 16, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('5.94'), 'UPI'),
#  (158, 24, datetime.datetime(2022, 11, 19, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('8.91'), 'Cash'),
#  (159, 33, datetime.datetime(2022, 11, 24, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('13.86'), 'Credit Card'),
#  (160, 47, datetime.datetime(2022, 12, 2, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('0.99'), 'UPI'),
#  (161, 48, datetime.datetime(2022, 12, 15, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('1.98'), 'Cash'),
#  (162, 50, datetime.datetime(2022, 12, 15, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('1.98'), 'Credit Card'),
#  (163, 52, datetime.datetime(2022, 12, 16, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('3.96'), 'UPI'),
#  (164, 56, datetime.datetime(2022, 12, 17, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('5.94'), 'Cash'),
#  (165, 3, datetime.datetime(2022, 12, 20, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('8.91'), 'Credit Card'),
#  (166, 12, datetime.datetime(2022, 12, 25, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('13.86'), 'UPI'),
#  (167, 26, datetime.datetime(2023, 1, 2, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('0.99'), 'Cash'),
#  (168, 27, datetime.datetime(2023, 1, 15, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('1.98'), 'Credit Card'),
#  (169, 29, datetime.datetime(2023, 1, 15, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('1.98'), 'UPI'),
#  (170, 31, datetime.datetime(2023, 1, 16, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('3.96'), 'Cash'),
#  (171, 35, datetime.datetime(2023, 1, 17, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('5.94'), 'Credit Card'),
#  (172, 41, datetime.datetime(2023, 1, 20, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('8.91'), 'UPI'),
#  (173, 50, datetime.datetime(2023, 1, 25, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('13.86'), 'Cash'),
#  (174, 5, datetime.datetime(2023, 2, 2, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('0.99'), 'Credit Card'),
#  (175, 6, datetime.datetime(2023, 2, 15, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('1.98'), 'UPI'),
#  (176, 8, datetime.datetime(2023, 2, 15, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('1.98'), 'Cash'),
#  (177, 10, datetime.datetime(2023, 2, 16, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('3.96'), 'Credit Card'),
#  (178, 14, datetime.datetime(2023, 2, 17, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('5.94'), 'UPI'),
#  (179, 20, datetime.datetime(2023, 2, 20, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('8.91'), 'Cash'),
#  (180, 29, datetime.datetime(2023, 2, 25, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('13.86'), 'Credit Card'),
#  (181, 43, datetime.datetime(2023, 3, 5, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('0.99'), 'UPI'),
#  (182, 44, datetime.datetime(2023, 3, 18, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('1.98'), 'Cash'),
#  (183, 46, datetime.datetime(2023, 3, 18, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('1.98'), 'Credit Card'),
#  (184, 48, datetime.datetime(2023, 3, 19, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('3.96'), 'UPI'),
#  (185, 52, datetime.datetime(2023, 3, 20, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('5.94'), 'Cash'),
#  (186, 58, datetime.datetime(2023, 3, 23, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('8.91'), 'Credit Card'),
#  (187, 8, datetime.datetime(2023, 3, 28, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('13.86'), 'UPI'),
#  (188, 22, datetime.datetime(2023, 4, 5, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('0.99'), 'Cash'),
#  (189, 23, datetime.datetime(2023, 4, 18, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('1.98'), 'Credit Card'),
#  (190, 25, datetime.datetime(2023, 4, 18, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('1.98'), 'UPI'),
#  (191, 27, datetime.datetime(2023, 4, 19, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('3.96'), 'Cash'),
#  (192, 31, datetime.datetime(2023, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 'Credit Card'),
#  (193, 37, datetime.datetime(2023, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 'UPI'),
#  (194, 46, datetime.datetime(2023, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 'Cash'),
#  (195, 1, datetime.datetime(2023, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 'Credit Card'),
#  (196, 2, datetime.datetime(2023, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 'UPI'),
#  (197, 4, datetime.datetime(2023, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 'Cash'),
#  (198, 6, datetime.datetime(2023, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 'Credit Card'),
#  (199, 10, datetime.datetime(2023, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 'UPI'),
#  (200, 16, datetime.datetime(2023, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 'Cash'),
#  (201, 25, datetime.datetime(2023, 5, 29, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('18.86'), 'Credit Card'),
#  (202, 39, datetime.datetime(2023, 6, 6, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('1.99'), 'UPI'),
#  (203, 40, datetime.datetime(2023, 6, 19, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('2.98'), 'Cash'),
#  (204, 42, datetime.datetime(2023, 6, 19, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.98'), 'Credit Card'),
#  (205, 44, datetime.datetime(2023, 6, 20, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('7.96'), 'UPI'),
#  (206, 48, datetime.datetime(2023, 6, 21, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('8.94'), 'Cash'),
#  (207, 54, datetime.datetime(2023, 6, 24, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('8.91'), 'Credit Card'),
#  (208, 4, datetime.datetime(2023, 6, 29, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('15.86'), 'UPI'),
#  (209, 18, datetime.datetime(2023, 7, 7, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('0.99'), 'Cash'),
#  (210, 19, datetime.datetime(2023, 7, 20, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 'Credit Card'),
#  (211, 21, datetime.datetime(2023, 7, 20, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('1.98'), 'UPI'),
#  (212, 23, datetime.datetime(2023, 7, 21, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('3.96'), 'Cash'),
#  (213, 27, datetime.datetime(2023, 7, 22, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('5.94'), 'Credit Card'),
#  (214, 33, datetime.datetime(2023, 7, 25, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('8.91'), 'UPI'),
#  (215, 42, datetime.datetime(2023, 7, 30, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('13.86'), 'Cash'),
#  (216, 56, datetime.datetime(2023, 8, 7, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('0.99'), 'Credit Card'),
#  (217, 57, datetime.datetime(2023, 8, 20, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 'UPI'),
#  (218, 59, datetime.datetime(2023, 8, 20, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('1.98'), 'Cash'),
#  (219, 2, datetime.datetime(2023, 8, 21, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('3.96'), 'Credit Card'),
#  (220, 6, datetime.datetime(2023, 8, 22, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('5.94'), 'UPI'),
#  (221, 12, datetime.datetime(2023, 8, 25, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('8.91'), 'Cash'),
#  (222, 21, datetime.datetime(2023, 8, 30, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('13.86'), 'Credit Card'),
#  (223, 35, datetime.datetime(2023, 9, 7, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('0.99'), 'UPI'),
#  (224, 36, datetime.datetime(2023, 9, 20, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 'Cash'),
#  (225, 38, datetime.datetime(2023, 9, 20, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 'Credit Card'),
#  (226, 40, datetime.datetime(2023, 9, 21, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('3.96'), 'UPI'),
#  (227, 44, datetime.datetime(2023, 9, 22, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('5.94'), 'Cash'),
#  (228, 50, datetime.datetime(2023, 9, 25, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('8.91'), 'Credit Card'),
#  (229, 59, datetime.datetime(2023, 9, 30, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('13.86'), 'UPI'),
#  (230, 14, datetime.datetime(2023, 10, 8, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('0.99'), 'Cash'),
#  (231, 15, datetime.datetime(2023, 10, 21, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('1.98'), 'Credit Card'),
#  (232, 17, datetime.datetime(2023, 10, 21, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 'UPI'),
#  (233, 19, datetime.datetime(2023, 10, 22, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('3.96'), 'Cash'),
#  (234, 23, datetime.datetime(2023, 10, 23, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('5.94'), 'Credit Card'),
#  (235, 29, datetime.datetime(2023, 10, 26, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('8.91'), 'UPI'),
#  (236, 38, datetime.datetime(2023, 10, 31, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('13.86'), 'Cash'),
#  (237, 52, datetime.datetime(2023, 11, 8, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('0.99'), 'Credit Card'),
#  (238, 53, datetime.datetime(2023, 11, 21, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('1.98'), 'UPI'),
#  (239, 55, datetime.datetime(2023, 11, 21, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 'Cash'),
#  (240, 57, datetime.datetime(2023, 11, 22, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('3.96'), 'Credit Card'),
#  (241, 2, datetime.datetime(2023, 11, 23, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('5.94'), 'UPI'),
#  (242, 8, datetime.datetime(2023, 11, 26, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('8.91'), 'Cash'),
#  (243, 17, datetime.datetime(2023, 12, 1, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('13.86'), 'Credit Card'),
#  (244, 31, datetime.datetime(2023, 12, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('0.99'), 'UPI'),
#  (245, 32, datetime.datetime(2023, 12, 22, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('1.98'), 'Cash'),
#  (246, 34, datetime.datetime(2023, 12, 22, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 'Credit Card'),
#  (247, 36, datetime.datetime(2023, 12, 23, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('3.96'), 'UPI'),
#  (248, 40, datetime.datetime(2023, 12, 24, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('5.94'), 'Cash'),
#  (249, 46, datetime.datetime(2023, 12, 27, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('8.91'), 'Credit Card'),
#  (250, 55, datetime.datetime(2024, 1, 1, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('13.86'), 'UPI'),
#  (251, 10, datetime.datetime(2024, 1, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('0.99'), 'Cash'),
#  (252, 11, datetime.datetime(2024, 1, 22, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('1.98'), 'Credit Card'),
#  (253, 13, datetime.datetime(2024, 1, 22, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('1.98'), 'UPI'),
#  (254, 15, datetime.datetime(2024, 1, 23, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('3.96'), 'Cash'),
#  (255, 19, datetime.datetime(2024, 1, 24, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('5.94'), 'Credit Card'),
#  (256, 25, datetime.datetime(2024, 1, 27, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('8.91'), 'UPI'),
#  (257, 34, datetime.datetime(2024, 2, 1, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('13.86'), 'Cash'),
#  (258, 48, datetime.datetime(2024, 2, 9, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('0.99'), 'Credit Card'),
#  (259, 49, datetime.datetime(2024, 2, 22, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('1.98'), 'UPI'),
#  (260, 51, datetime.datetime(2024, 2, 22, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('1.98'), 'Cash'),
#  (261, 53, datetime.datetime(2024, 2, 23, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('3.96'), 'Credit Card'),
#  (262, 57, datetime.datetime(2024, 2, 24, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('5.94'), 'UPI'),
#  (263, 4, datetime.datetime(2024, 2, 27, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('8.91'), 'Cash'),
#  (264, 13, datetime.datetime(2024, 3, 3, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('13.86'), 'Credit Card'),
#  (265, 27, datetime.datetime(2024, 3, 11, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('0.99'), 'UPI'),
#  (266, 28, datetime.datetime(2024, 3, 24, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('1.98'), 'Cash'),
#  (267, 30, datetime.datetime(2024, 3, 24, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('1.98'), 'Credit Card'),
#  (268, 32, datetime.datetime(2024, 3, 25, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('3.96'), 'UPI'),
#  (269, 36, datetime.datetime(2024, 3, 26, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('5.94'), 'Cash'),
#  (270, 42, datetime.datetime(2024, 3, 29, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('8.91'), 'Credit Card'),
#  (271, 51, datetime.datetime(2024, 4, 3, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('13.86'), 'UPI'),
#  (272, 6, datetime.datetime(2024, 4, 11, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('0.99'), 'Cash'),
#  (273, 7, datetime.datetime(2024, 4, 24, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('1.98'), 'Credit Card'),
#  (274, 9, datetime.datetime(2024, 4, 24, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('1.98'), 'UPI'),
#  (275, 11, datetime.datetime(2024, 4, 25, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('3.96'), 'Cash'),
#  (276, 15, datetime.datetime(2024, 4, 26, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('5.94'), 'Credit Card'),
#  (277, 21, datetime.datetime(2024, 4, 29, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('8.91'), 'UPI'),
#  (278, 30, datetime.datetime(2024, 5, 4, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('13.86'), 'Cash'),
#  (279, 44, datetime.datetime(2024, 5, 12, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('0.99'), 'Credit Card'),
#  (280, 45, datetime.datetime(2024, 5, 25, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('1.98'), 'UPI'),
#  (281, 47, datetime.datetime(2024, 5, 25, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('1.98'), 'Cash'),
#  (282, 49, datetime.datetime(2024, 5, 26, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('3.96'), 'Credit Card'),
#  (283, 53, datetime.datetime(2024, 5, 27, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('5.94'), 'UPI'),
#  (284, 59, datetime.datetime(2024, 5, 30, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('8.91'), 'Cash'),
#  (285, 9, datetime.datetime(2024, 6, 4, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('13.86'), 'Credit Card'),
#  (286, 23, datetime.datetime(2024, 6, 12, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('0.99'), 'UPI'),
#  (287, 24, datetime.datetime(2024, 6, 25, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('1.98'), 'Cash'),
#  (288, 26, datetime.datetime(2024, 6, 25, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('1.98'), 'Credit Card'),
#  (289, 28, datetime.datetime(2024, 6, 26, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('3.96'), 'UPI'),
#  (290, 32, datetime.datetime(2024, 6, 27, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('5.94'), 'Cash'),
#  (291, 38, datetime.datetime(2024, 6, 30, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('8.91'), 'Credit Card'),
#  (292, 47, datetime.datetime(2024, 7, 5, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('13.86'), 'UPI'),
#  (293, 2, datetime.datetime(2024, 7, 13, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('0.99'), 'Cash'),
#  (294, 3, datetime.datetime(2024, 7, 26, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('1.98'), 'Credit Card'),
#  (295, 5, datetime.datetime(2024, 7, 26, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('1.98'), 'UPI'),
#  (296, 7, datetime.datetime(2024, 7, 27, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('3.96'), 'Cash'),
#  (297, 11, datetime.datetime(2024, 7, 28, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('5.94'), 'Credit Card'),
#  (298, 17, datetime.datetime(2024, 7, 31, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('10.91'), 'UPI'),
#  (299, 26, datetime.datetime(2024, 8, 5, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('23.86'), 'Cash'),
#  (300, 40, datetime.datetime(2024, 8, 13, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('0.99'), 'Credit Card'),
#  (301, 41, datetime.datetime(2024, 8, 26, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('1.98'), 'UPI'),
#  (302, 43, datetime.datetime(2024, 8, 26, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('1.98'), 'Cash'),
#  (303, 45, datetime.datetime(2024, 8, 27, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('3.96'), 'Credit Card'),
#  (304, 49, datetime.datetime(2024, 8, 28, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('5.94'), 'UPI'),
#  (305, 55, datetime.datetime(2024, 8, 31, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('8.91'), 'Cash'),
#  (306, 5, datetime.datetime(2024, 9, 5, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('16.86'), 'Credit Card'),
#  (307, 19, datetime.datetime(2024, 9, 13, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.99'), 'UPI'),
#  (308, 20, datetime.datetime(2024, 9, 26, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('3.98'), 'Cash'),
#  (309, 22, datetime.datetime(2024, 9, 26, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('3.98'), 'Credit Card'),
#  (310, 24, datetime.datetime(2024, 9, 27, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('7.96'), 'UPI'),
#  (311, 28, datetime.datetime(2024, 9, 28, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('11.94'), 'Cash'),
#  (312, 34, datetime.datetime(2024, 10, 1, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('10.91'), 'Credit Card'),
#  (313, 43, datetime.datetime(2024, 10, 6, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('16.86'), 'UPI'),
#  (314, 57, datetime.datetime(2024, 10, 14, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('0.99'), 'Cash'),
#  (315, 58, datetime.datetime(2024, 10, 27, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('1.98'), 'Credit Card'),
#  (316, 1, datetime.datetime(2024, 10, 27, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('1.98'), 'UPI'),
#  (317, 3, datetime.datetime(2024, 10, 28, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('3.96'), 'Cash'),
#  (318, 7, datetime.datetime(2024, 10, 29, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('5.94'), 'Credit Card'),
#  (319, 13, datetime.datetime(2024, 11, 1, 0, 0), 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', Decimal('8.91'), 'UPI'),
#  (320, 22, datetime.datetime(2024, 11, 6, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('13.86'), 'Cash'),
#  (321, 36, datetime.datetime(2024, 11, 14, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('0.99'), 'Credit Card'),
#  (322, 37, datetime.datetime(2024, 11, 27, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('1.98'), 'UPI'),
#  (323, 39, datetime.datetime(2024, 11, 27, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('1.98'), 'Cash'),
#  (324, 41, datetime.datetime(2024, 11, 28, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('3.96'), 'Credit Card'),
#  (325, 45, datetime.datetime(2024, 11, 29, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('5.94'), 'UPI'),
#  (326, 51, datetime.datetime(2024, 12, 2, 0, 0), 'Celsiusg. 9', 'Stockholm', None, 'Sweden', '11230', Decimal('8.91'), 'Cash'),
#  (327, 1, datetime.datetime(2024, 12, 7, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('13.86'), 'Credit Card'),
#  (328, 15, datetime.datetime(2024, 12, 15, 0, 0), '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', Decimal('0.99'), 'UPI'),
#  (329, 16, datetime.datetime(2024, 12, 28, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('1.98'), 'Cash'),
#  (330, 18, datetime.datetime(2024, 12, 28, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('1.98'), 'Credit Card'),
#  (331, 20, datetime.datetime(2024, 12, 29, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('3.96'), 'UPI'),
#  (332, 24, datetime.datetime(2024, 12, 30, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('5.94'), 'Cash'),
#  (333, 30, datetime.datetime(2025, 1, 2, 0, 0), '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', Decimal('8.91'), 'Credit Card'),
#  (334, 39, datetime.datetime(2025, 1, 7, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('13.86'), 'UPI'),
#  (335, 53, datetime.datetime(2025, 1, 15, 0, 0), '113 Lupus St', 'London', None, 'United Kingdom', 'SW1V 3EN', Decimal('0.99'), 'Cash'),
#  (336, 54, datetime.datetime(2025, 1, 28, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('1.98'), 'Credit Card'),
#  (337, 56, datetime.datetime(2025, 1, 28, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('1.98'), 'UPI'),
#  (338, 58, datetime.datetime(2025, 1, 29, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('3.96'), 'Cash'),
#  (339, 3, datetime.datetime(2025, 1, 30, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('5.94'), 'Credit Card'),
#  (340, 9, datetime.datetime(2025, 2, 2, 0, 0), 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', Decimal('8.91'), 'UPI'),
#  (341, 18, datetime.datetime(2025, 2, 7, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('13.86'), 'Cash'),
#  (342, 32, datetime.datetime(2025, 2, 15, 0, 0), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('0.99'), 'Credit Card'),
#  (343, 33, datetime.datetime(2025, 2, 28, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('1.98'), 'UPI'),
#  (344, 35, datetime.datetime(2025, 2, 28, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('1.98'), 'Cash'),
#  (345, 37, datetime.datetime(2025, 3, 1, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('3.96'), 'Credit Card'),
#  (346, 41, datetime.datetime(2025, 3, 2, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('5.94'), 'UPI'),
#  (347, 47, datetime.datetime(2025, 3, 5, 0, 0), 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', Decimal('8.91'), 'Cash'),
#  (348, 56, datetime.datetime(2025, 3, 10, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('13.86'), 'Credit Card'),
#  (349, 11, datetime.datetime(2025, 3, 18, 0, 0), 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', Decimal('0.99'), 'UPI'),
#  (350, 12, datetime.datetime(2025, 3, 31, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('1.98'), 'Cash'),
#  (351, 14, datetime.datetime(2025, 3, 31, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('1.98'), 'Credit Card'),
#  (352, 16, datetime.datetime(2025, 4, 1, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('3.96'), 'UPI'),
#  (353, 20, datetime.datetime(2025, 4, 2, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('5.94'), 'Cash'),
#  (354, 26, datetime.datetime(2025, 4, 5, 0, 0), '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', Decimal('8.91'), 'Credit Card'),
#  (355, 35, datetime.datetime(2025, 4, 10, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('13.86'), 'UPI'),
#  (356, 49, datetime.datetime(2025, 4, 18, 0, 0), 'Ordynacka 10', 'Warsaw', None, 'Poland', '00-358', Decimal('0.99'), 'Cash'),
#  (357, 50, datetime.datetime(2025, 5, 1, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('1.98'), 'Credit Card'),
#  (358, 52, datetime.datetime(2025, 5, 1, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('1.98'), 'UPI'),
#  (359, 54, datetime.datetime(2025, 5, 2, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('3.96'), 'Cash'),
#  (360, 58, datetime.datetime(2025, 5, 3, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('5.94'), 'Credit Card'),
#  (361, 5, datetime.datetime(2025, 5, 6, 0, 0), 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', Decimal('8.91'), 'UPI'),
#  (362, 14, datetime.datetime(2025, 5, 11, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('13.86'), 'Cash'),
#  (363, 28, datetime.datetime(2025, 5, 19, 0, 0), '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', Decimal('0.99'), 'Credit Card'),
#  (364, 29, datetime.datetime(2025, 6, 1, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('1.98'), 'UPI'),
#  (365, 31, datetime.datetime(2025, 6, 1, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('1.98'), 'Cash'),
#  (366, 33, datetime.datetime(2025, 6, 2, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('3.96'), 'Credit Card'),
#  (367, 37, datetime.datetime(2025, 6, 3, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('5.94'), 'UPI'),
#  (368, 43, datetime.datetime(2025, 6, 6, 0, 0), '68, Rue Jouvence', 'Dijon', None, 'France', '21000', Decimal('8.91'), 'Cash'),
#  (369, 52, datetime.datetime(2025, 6, 11, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('13.86'), 'Credit Card'),
#  (370, 7, datetime.datetime(2025, 6, 19, 0, 0), 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', Decimal('0.99'), 'UPI'),
#  (371, 8, datetime.datetime(2025, 7, 2, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('1.98'), 'Cash'),
#  (372, 10, datetime.datetime(2025, 7, 2, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('1.98'), 'Credit Card'),
#  (373, 12, datetime.datetime(2025, 7, 3, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('3.96'), 'UPI'),
#  (374, 16, datetime.datetime(2025, 7, 4, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('5.94'), 'Cash'),
#  (375, 22, datetime.datetime(2025, 7, 7, 0, 0), '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', Decimal('8.91'), 'Credit Card'),
#  (376, 31, datetime.datetime(2025, 7, 12, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('13.86'), 'UPI'),
#  (377, 45, datetime.datetime(2025, 7, 20, 0, 0), 'Erzsébet krt. 58.', 'Budapest', None, 'Hungary', 'H-1073', Decimal('0.99'), 'Cash'),
#  (378, 46, datetime.datetime(2025, 8, 2, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('1.98'), 'Credit Card'),
#  (379, 48, datetime.datetime(2025, 8, 2, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('1.98'), 'UPI'),
#  (380, 50, datetime.datetime(2025, 8, 3, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('3.96'), 'Cash'),
#  (381, 54, datetime.datetime(2025, 8, 4, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('5.94'), 'Credit Card'),
#  (382, 1, datetime.datetime(2025, 8, 7, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('8.91'), 'UPI'),
#  (383, 10, datetime.datetime(2025, 8, 12, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('13.86'), 'Cash'),
#  (384, 24, datetime.datetime(2025, 8, 20, 0, 0), '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', Decimal('0.99'), 'Credit Card'),
#  (385, 25, datetime.datetime(2025, 9, 2, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('1.98'), 'UPI'),
#  (386, 27, datetime.datetime(2025, 9, 2, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('1.98'), 'Cash'),
#  (387, 29, datetime.datetime(2025, 9, 3, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('3.96'), 'Credit Card'),
#  (388, 33, datetime.datetime(2025, 9, 4, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('5.94'), 'UPI'),
#  (389, 39, datetime.datetime(2025, 9, 7, 0, 0), '4, Rue Milton', 'Paris', None, 'France', '75009', Decimal('8.91'), 'Cash'),
#  (390, 48, datetime.datetime(2025, 9, 12, 0, 0), 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', Decimal('13.86'), 'Credit Card'),
#  (391, 3, datetime.datetime(2025, 9, 20, 0, 0), '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', Decimal('0.99'), 'UPI'),
#  (392, 4, datetime.datetime(2025, 10, 3, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 'Cash'),
#  (393, 6, datetime.datetime(2025, 10, 3, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('1.98'), 'Credit Card'),
#  (394, 8, datetime.datetime(2025, 10, 4, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('3.96'), 'UPI'),
#  (395, 12, datetime.datetime(2025, 10, 5, 0, 0), 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', Decimal('5.94'), 'Cash'),
#  (396, 18, datetime.datetime(2025, 10, 8, 0, 0), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('8.91'), 'Credit Card'),
#  (397, 27, datetime.datetime(2025, 10, 13, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('13.86'), 'UPI'),
#  (398, 41, datetime.datetime(2025, 10, 21, 0, 0), '11, Place Bellecour', 'Lyon', None, 'France', '69002', Decimal('0.99'), 'Cash'),
#  (399, 42, datetime.datetime(2025, 11, 3, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('1.98'), 'Credit Card'),
#  (400, 44, datetime.datetime(2025, 11, 3, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('1.98'), 'UPI'),
#  (401, 46, datetime.datetime(2025, 11, 4, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('3.96'), 'Cash'),
#  (402, 50, datetime.datetime(2025, 11, 5, 0, 0), 'C/ San Bernardo 85', 'Madrid', None, 'Spain', '28015', Decimal('5.94'), 'Credit Card'),
#  (403, 56, datetime.datetime(2025, 11, 8, 0, 0), '307 Macacha Güemes', 'Buenos Aires', None, 'Argentina', '1106', Decimal('8.91'), 'UPI'),
#  (404, 6, datetime.datetime(2025, 11, 13, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('25.86'), 'Cash'),
#  (405, 20, datetime.datetime(2025, 11, 21, 0, 0), '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', Decimal('0.99'), 'Credit Card'),
#  (406, 21, datetime.datetime(2025, 12, 4, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('1.98'), 'UPI'),
#  (407, 23, datetime.datetime(2025, 12, 4, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('1.98'), 'Cash'),
#  (408, 25, datetime.datetime(2025, 12, 5, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('3.96'), 'Credit Card'),
#  (409, 29, datetime.datetime(2025, 12, 6, 0, 0), '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', Decimal('5.94'), 'UPI'),
#  (410, 35, datetime.datetime(2025, 12, 9, 0, 0), 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', None, 'Portugal', None, Decimal('8.91'), 'Cash'),
#  (411, 44, datetime.datetime(2025, 12, 14, 0, 0), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('13.86'), 'Credit Card'),
#  (412, 58, datetime.datetime(2025, 12, 22, 0, 0), '12,Community Centre', 'Delhi', None, 'India', '110017', Decimal('1.99'), 'UPI')]
